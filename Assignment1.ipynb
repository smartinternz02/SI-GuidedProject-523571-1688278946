# %%
import numpy as np
import pandas as pd

# %%
num_random= np.random.randint(1,10,size=(4,4))

num_random
# Out:
# array([[6, 4, 7, 1],
#        [9, 7, 1, 6],
#        [3, 8, 5, 6],
#        [4, 9, 8, 2]])

# %%
df=pd.DataFrame(num_random, columns=["High","Low","Medium","Normal"])

df
# Out:
#    High  Low  Medium  Normal
# 0     6    4       7       1
# 1     9    7       1       6
# 2     3    8       5       6
# 3     4    9       8       2

# %%
df.rename(columns={"High":"Random Value 1","Low":"Random Value 2","Medium":"Random Value 3","Normal":"Random Value 4"}, inplace= True)

df
# Out:
#    Random Value 1  Random Value 2  Random Value 3  Random Value 4
# 0               6               4               7               1
# 1               9               7               1               6
# 2               3               8               5               6
# 3               4               9               8               2

# %%
df.columns
# Out:
# Index(['Random Value 1', 'Random Value 2', 'Random Value 3', 'Random Value 4'], dtype='object')

# %%
df.describe()
# Out:
#        Random Value 1  Random Value 2  Random Value 3  Random Value 4
# count        4.000000        4.000000        4.000000        4.000000
# mean         5.500000        7.000000        5.250000        3.750000
# std          2.645751        2.160247        3.095696        2.629956
# min          3.000000        4.000000        1.000000        1.000000
# 25%          3.750000        6.250000        4.000000        1.750000
# 50%          5.000000        7.500000        6.000000        4.000000
# 75%          6.750000        8.250000        7.250000        6.000000
# max          9.000000        9.000000        8.000000        6.000000

# %%
df.isnull()
# Out:
#    Random Value 1  Random Value 2  Random Value 3  Random Value 4
# 0           False           False           False           False
# 1           False           False           False           False
# 2           False           False           False           False
# 3           False           False           False           False

# %%
df.dtypes
# Out:
# Random Value 1    int64
# Random Value 2    int64
# Random Value 3    int64
# Random Value 4    int64
# dtype: object

# %%
df.loc[:,["Random Value 2","Random Value 3"]]
# Out:
#    Random Value 2  Random Value 3
# 0               4               7
# 1               7               1
# 2               8               5
# 3               9               8

# %%
df.iloc[:,[1,2]]
# Out:
#    Random Value 2  Random Value 3
# 0               4               7
# 1               7               1
# 2               8               5
# 3               9               8
